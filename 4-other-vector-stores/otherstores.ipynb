# %% [markdown]
# In Memory vector
# uses a dectinoary and computes the cosine similarity for the search using numpy

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
llm=init_chat_model(model="openai/gpt-oss-120b")
