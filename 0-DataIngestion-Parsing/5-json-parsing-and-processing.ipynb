# %%
import os
import json
os.makedirs('data/json-files',exist_ok=True)

# %%
data=[
  {
    "Product": "Wireless Mouse",
    "Category": "Electronics",
    "Price": 25.99,
    "Stock": 120,
    "Description": "Ergonomic wireless mouse with 2.4GHz connectivity."
  },
  {
    "Product": "Yoga Mat",
    "Category": "Fitness",
    "Price": 15.50,
    "Stock": 80,
    "Description": "Eco-friendly mat with non-slip surface."
  },
  {
    "Product": "Coffee Maker",
    "Category": "Home Appliances",
    "Price": 89.00,
    "Stock": 45,
    "Description": "Programmable coffee maker with 12-cup capacity."
  }
]

# %%
data
# Out:
# [{'Product': 'Wireless Mouse',
#   'Category': 'Electronics',
#   'Price': 25.99,
#   'Stock': 120,
#   'Description': 'Ergonomic wireless mouse with 2.4GHz connectivity.'},
#  {'Product': 'Yoga Mat',
#   'Category': 'Fitness',
#   'Price': 15.5,
#   'Stock': 80,
#   'Description': 'Eco-friendly mat with non-slip surface.'},
#  {'Product': 'Coffee Maker',
#   'Category': 'Home Appliances',
#   'Price': 89.0,
#   'Stock': 45,
#   'Description': 'Programmable coffee maker with 12-cup capacity.'}]

# %%
with open('data/json_files/company.json','w') as f:
    json.dump(data,f,indent=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open('data/json_files/company.json','w') as f:
#       2     json.dump(data,f,indent=2)
#
# File c:\Users\PARAS\Downloads\krish-naik-new-course\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/json_files/company.json'
