# %%
#This is an project Based upon MultiMOdel Ipynb

# %%
import os
from dotenv import load_dotenv
load_dotenv()

clip_model=CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_pretrained=CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
clip_model.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from dotenv import load_dotenv
#       3 load_dotenv()
# ----> 5 clip_model=CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
#       6 clip_pretrained=CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
#       7 clip_model.eval()
#
# NameError: name 'CLIPModel' is not defined

# %%
#Embeedings function
def embed_image(image_data):
    """Embed Image using CLIP"""
    if isinstance(image_data,str):
        image=Image.open(image_data).convert("R&B")
    else:
        image=image_data
    clip_processor(images=image,retrun_tensor="pt")
