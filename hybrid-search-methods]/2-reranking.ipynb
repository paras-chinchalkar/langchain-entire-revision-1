# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain_core.document_loaders import TextLoader
#
# ImportError: cannot import name 'TextLoader' from 'langchain_core.document_loaders' (c:\Users\PARAS\Downloads\krish-naik-new-course\.venv\Lib\site-packages\langchain_core\document_loaders\__init__.py)
